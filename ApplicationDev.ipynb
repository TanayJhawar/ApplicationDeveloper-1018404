# %%
import json
from collections import defaultdict
from datetime import datetime, timedelta

# %%
def read_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
file_path = "trainings.txt"
data = read_json_file(file_path)

# %%
def list_completed_trainings(data):
    completed_trainings = defaultdict(set)

    for person in data:
        person_name = person['name']

        for completion in person['completions']:
            training_name = completion['name']
            completed_trainings[training_name].add(person_name)

    # Convert sets to counts before returning the result
    result = {training_name: len(people) for training_name, people in completed_trainings.items()}

    return result

# %%
# Task 1: List each completed training with a count of how many people have completed that training.
completed_trainings = list_completed_trainings(data)
print("Completed Trainings:")
print(json.dumps(completed_trainings, indent=2))

import os

# Save the result to a JSON file
with open('task1.json', 'w') as outfile:
    json.dump(completed_trainings, outfile, indent=2)
# Out:
# Completed Trainings:
# {
#   "Electrical Safety for Labs": 118,
#   "Safe Handling of Human Cell Lines/Materials in a Research Laboratory": 99,
#   "Awareness Training for the Transport of Hazardous Material": 110,
#   "X-Ray Safety": 118,
#   "Radiation Safety Annual Refresher": 121,
#   "Using Hazardous Chemicals in an Animal Care Facility": 115,
#   "Chemical Waste Requirements": 111,
#   "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle": 114,
#   "Transportation of Infectious Substances, Category B": 107,
#   "Working in Cold Temperatures": 110,
#   "Occupational Exposure to Bloodborne Pathogens": 102,
#   "Laboratory Safety Training": 113,
#   "Basic Training Program for Animal Users": 113,
#   "Physical Science Responsible Conduct of Research Course 1.": 111,
#   "Animal Care And Use Risk Assessment": 99,
#   "Understanding Biosafety": 123,
#   "NIH Guidelines Overview": 94,
#   "Radioactive Materials Safety Training": 121,
#   "Health Screening Questionnaire": 114,
#   "DOT Hazard Material Awareness": 116,
#   "IRB Quiz": 99,
#   "OHS Training": 116,
#   "Retraining in working with the IACUC": 114,
#   "Federally Required RCR Training - Must be delivered by PI (Not available online)": 114,
#   "Medical Records": 104
# }

# %%
def list_people_by_training_and_fiscal_year(data, trainings, fiscal_year):
    result = {}
    start_date = datetime.strptime(f"{str(int(fiscal_year)-1)}-07-01", '%Y-%m-%d')
    end_date = datetime.strptime(f"{fiscal_year}-06-30", '%Y-%m-%d')

    for person in data:
        for completion in person['completions']:
            training_name = completion['name']
            completion_date = datetime.strptime(completion['timestamp'], '%m/%d/%Y')

            if training_name in trainings and start_date <= completion_date <= end_date:
                result.setdefault(training_name, set()).add(person['name'])

    # Convert sets to lists before returning the result
    result = {training_name: list(people) for training_name, people in result.items()}

    return result

# %%
trainings_list = ["Electrical Safety for Labs", "X-Ray Safety", "Laboratory Safety Training"]
fiscal_year = "2024"
people_by_training = list_people_by_training_and_fiscal_year(data, trainings_list, fiscal_year)
print("\nPeople by Training and Fiscal Year:")
print(json.dumps(people_by_training, indent=2))

# Save the result to a JSON file
with open('task2.json', 'w') as outfile:
    json.dump(completed_trainings, outfile, indent=2)
# Out:
# People by Training and Fiscal Year:
# {
#   "X-Ray Safety": [
#     "Brynn Marks",
#     "Blaze Joyce",
#     "Rayan Valencia",
#     "Ezra Powers",
#     "Hadassah Hampton",
#     "Gloria Mccarty",
#     "Ann Knight",
#     "Anabelle Braun",
#     "Cloe Williamson",
#     "Reese Raymond",
#     "Antwan Villanueva",
#     "Mitchell Ware",
#     "Ainsley Drake",
#     "Misael Becker",
#     "Irvin Estrada",
#     "Noemi Cisneros",
#     "Destinee Odonnell",
#     "Soren Chaney",
#     "Asia Duke",
#     "Jagger Hoffman",
#     "Nayeli Ortiz"
#   ],
#   "Laboratory Safety Training": [
#     "Zane Mcgrath",
#     "Skye Valenzuela",
#     "Annabella Jacobson",
#     "Dawson Compton",
#     "Matias Oconnell",
#     "Makenzie Pollard",
#     "Niko Frey",
#     "Nayeli Mckenzie",
#     "Eden Nash",
#     "Sasha Armstrong",
#     "Lawson Quinn",
#     "Ariella David",
#     "Noah Burch",
#     "Roy Robbins",
#     "Travis Grant",
#     "Karli Craig",
#     "Conner Warner",
#     "Vaughn Mcmillan",
#     "Dania Parrish",
#     "Kaitlyn Orozco"
#   ],
#   "Electrical Safety for Labs": [
#     "Sandra Manning",
#     "Allie Barnes",
#     "Brogan Stein",
#     "Antwan Villanueva",
#     "Gerald Parsons",
#     "Jamison Lawson",
#     "Reed Ramos",
#     "Armani Tapia",
#     "Desiree Potts",
#     "Calvin Rubio",
#     "Teresa Esparza",
#     "Audrina Eaton",
#     "Humberto Huerta",
#     "Kierra Grimes",
#     "Charity Lucas",
#     "Lexie Ho",
#     "Martin Dean",
#     "Zavier Maldonado",
#     "Leandro Krause"
#   ]
# }

# %%
def find_expired_trainings(data, reference_date):
    result = [
        {
            'name': person['name'],
            'completions': [
                {
                    'name': completion['name'],
                    'timestamp': datetime.strptime(completion['timestamp'], '%m/%d/%Y').strftime('%m/%d/%Y'),
                    'expires': datetime.strptime(completion['expires'], '%m/%d/%Y').strftime('%m/%d/%Y') if completion['expires'] else None,
                    'expired_status': 'expired' if completion['expires'] and datetime.strptime(completion['expires'], '%m/%d/%Y') < reference_date else 'expires_soon'
                }
                for completion in person['completions']
                if completion.get('expires') and (
                    datetime.strptime(completion['expires'], '%m/%d/%Y') < reference_date
                    or (datetime.strptime(completion['expires'], '%m/%d/%Y') >= reference_date and datetime.strptime(completion['expires'], '%m/%d/%Y') <= reference_date + timedelta(days=30))
                )
            ]
        }
        for person in data
        if any(completion.get('expires') for completion in person['completions'])
    ]

    result = [entry for entry in result if entry['completions']]  # Remove entries with empty completions
    return result

# %%
reference_date = datetime.strptime('10/01/2023', '%m/%d/%Y')
expired_trainings = find_expired_trainings(data, reference_date)
json_output = json.dumps(expired_trainings, indent=2)
print(json_output)

# Save the result to a JSON file
with open('task3.json', 'w') as outfile:
    json.dump(completed_trainings, outfile, indent=2)
# Out:
# [
#   {
#     "name": "Muhammad Kaufman",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "09/01/2022",
#         "expires": "09/01/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lexie Mckinney",
#     "completions": [
#       {
#         "name": "IRB Quiz",
#         "timestamp": "01/20/2022",
#         "expires": "01/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Gretchen Boyer",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "08/10/2022",
#         "expires": "08/10/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Denise Allen",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "06/27/2022",
#         "expires": "06/27/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "01/29/2022",
#         "expires": "01/29/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mila Baird",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "06/16/2022",
#         "expires": "06/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Arianna Esparza",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "05/02/2022",
#         "expires": "05/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Walker Wall",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "06/09/2022",
#         "expires": "06/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lucille Stout",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "12/25/2021",
#         "expires": "12/25/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Giovanny Gonzales",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "02/20/2022",
#         "expires": "02/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Marquis Forbes",
#     "completions": [
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "06/19/2022",
#         "expires": "06/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jeffery Kelly",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "04/17/2022",
#         "expires": "04/17/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "05/22/2022",
#         "expires": "05/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Emily Spence",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "12/22/2021",
#         "expires": "12/22/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Tiana Barron",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "04/04/2022",
#         "expires": "04/04/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "03/12/2022",
#         "expires": "03/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Dalia King",
#     "completions": [
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "02/28/2022",
#         "expires": "02/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Barbara Mclaughlin",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "02/18/2022",
#         "expires": "02/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Frank Zuniga",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "03/29/2022",
#         "expires": "03/29/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Nayeli Ortiz",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "02/25/2022",
#         "expires": "02/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Rayan Curry",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "01/07/2022",
#         "expires": "01/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jasmine Graham",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "12/25/2021",
#         "expires": "12/25/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Molly James",
#     "completions": [
#       {
#         "name": "Electrical Safety for Labs",
#         "timestamp": "01/08/2022",
#         "expires": "01/08/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Carl Riley",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "01/30/2022",
#         "expires": "01/30/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Zion Werner",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "01/21/2022",
#         "expires": "01/21/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "06/02/2022",
#         "expires": "06/02/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Medical Records",
#         "timestamp": "12/11/2021",
#         "expires": "12/11/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Ari Jimenez",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "05/18/2022",
#         "expires": "05/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Isla Watts",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "01/25/2022",
#         "expires": "01/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Marcus Tanner",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "06/14/2022",
#         "expires": "06/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Shane Landry",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "04/28/2022",
#         "expires": "04/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Rubi Klein",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "03/24/2022",
#         "expires": "03/24/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "09/16/2022",
#         "expires": "09/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Marshall Hutchinson",
#     "completions": [
#       {
#         "name": "IRB Quiz",
#         "timestamp": "07/08/2022",
#         "expires": "07/08/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Leticia Johnson",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "06/01/2022",
#         "expires": "06/01/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Chloe Wall",
#     "completions": [
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "07/12/2022",
#         "expires": "07/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lexie Ho",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "02/05/2022",
#         "expires": "02/05/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jamison Lawson",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "03/17/2022",
#         "expires": "03/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Zavier Maldonado",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "08/09/2022",
#         "expires": "08/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Enrique Burke",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "01/23/2022",
#         "expires": "01/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Emmett Sanchez",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "06/04/2022",
#         "expires": "06/04/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "IRB Quiz",
#         "timestamp": "07/12/2022",
#         "expires": "07/12/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Medical Records",
#         "timestamp": "05/28/2022",
#         "expires": "05/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Vicente Alvarez",
#     "completions": [
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "05/15/2022",
#         "expires": "05/15/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Adriana Figueroa",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "06/12/2022",
#         "expires": "06/12/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "06/07/2022",
#         "expires": "06/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lola Townsend",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "01/01/2022",
#         "expires": "01/01/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "07/09/2022",
#         "expires": "07/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Alberto Everett",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "09/12/2022",
#         "expires": "09/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Justice Quinn",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "03/14/2022",
#         "expires": "03/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Cameron Moody",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "09/20/2022",
#         "expires": "09/20/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "05/28/2022",
#         "expires": "05/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Rolando Schmitt",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "04/18/2022",
#         "expires": "04/18/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "03/15/2022",
#         "expires": "03/15/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Colby Trevino",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "08/02/2022",
#         "expires": "08/02/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "OHS Training",
#         "timestamp": "10/19/2022",
#         "expires": "10/19/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Jolie Diaz",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "09/25/2022",
#         "expires": "09/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kyler Cardenas",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "05/16/2022",
#         "expires": "05/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Liliana Sanders",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "03/19/2022",
#         "expires": "03/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Sage Rosales",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "10/31/2022",
#         "expires": "10/31/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Teagan French",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "08/21/2022",
#         "expires": "08/21/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Frankie Dennis",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "07/28/2022",
#         "expires": "07/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Gisselle Hooper",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "05/04/2022",
#         "expires": "05/04/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "04/07/2022",
#         "expires": "04/07/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "04/27/2022",
#         "expires": "04/27/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Vance Stout",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "07/10/2022",
#         "expires": "07/10/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "01/01/2022",
#         "expires": "01/01/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Deacon Hanson",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "08/16/2022",
#         "expires": "08/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Tiara Waters",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "10/01/2022",
#         "expires": "10/01/2023",
#         "expired_status": "expires_soon"
#       },
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "06/29/2022",
#         "expires": "06/29/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jeramiah Rogers",
#     "completions": [
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "10/09/2022",
#         "expires": "10/09/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Fernanda Green",
#     "completions": [
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "07/27/2022",
#         "expires": "07/27/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Wayne Howell",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "06/10/2022",
#         "expires": "06/10/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "12/13/2021",
#         "expires": "12/13/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Sonia Bowman",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "01/18/2022",
#         "expires": "01/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Makaila Hood",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "01/30/2022",
#         "expires": "01/30/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Rolando Shelton",
#     "completions": [
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "03/06/2022",
#         "expires": "03/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Claire Montes",
#     "completions": [
#       {
#         "name": "Physical Science Responsible Conduct of Research Course 1.",
#         "timestamp": "12/11/2021",
#         "expires": "12/11/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Skyla Lang",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "01/23/2022",
#         "expires": "01/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Gerald Parsons",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "03/21/2022",
#         "expires": "03/21/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Adan Lowery",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "03/16/2022",
#         "expires": "03/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Barrett Hicks",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "10/24/2022",
#         "expires": "10/24/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Davion Pena",
#     "completions": [
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "01/31/2022",
#         "expires": "01/31/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "02/23/2022",
#         "expires": "02/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kyla Walker",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "06/22/2022",
#         "expires": "06/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Aliya Chan",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "02/16/2022",
#         "expires": "02/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lukas Riggs",
#     "completions": [
#       {
#         "name": "Physical Science Responsible Conduct of Research Course 1.",
#         "timestamp": "06/07/2022",
#         "expires": "06/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Maggie Vincent",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "08/20/2022",
#         "expires": "08/20/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "10/09/2022",
#         "expires": "10/09/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Molly Singh",
#     "completions": [
#       {
#         "name": "Electrical Safety for Labs",
#         "timestamp": "05/14/2022",
#         "expires": "05/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Robert Daugherty",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "03/01/2022",
#         "expires": "03/01/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Dawson Compton",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "05/03/2022",
#         "expires": "05/03/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Aubree Gutierrez",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "08/18/2022",
#         "expires": "08/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Reid Arias",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "09/10/2022",
#         "expires": "09/10/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Medical Records",
#         "timestamp": "09/18/2022",
#         "expires": "09/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Norah Villegas",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "01/09/2022",
#         "expires": "01/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Rory Leonard",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "01/06/2022",
#         "expires": "01/06/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "04/08/2022",
#         "expires": "04/08/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "OHS Training",
#         "timestamp": "03/13/2022",
#         "expires": "03/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kenyon Estes",
#     "completions": [
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "08/16/2022",
#         "expires": "08/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Angelo Jimenez",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "05/16/2022",
#         "expires": "05/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Trinity Anthony",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "06/08/2022",
#         "expires": "06/08/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Raquel Dunn",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "09/15/2022",
#         "expires": "09/15/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Dania Parrish",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "12/09/2021",
#         "expires": "12/09/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kennedi Wolf",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "03/09/2022",
#         "expires": "03/09/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "09/11/2022",
#         "expires": "09/11/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "05/29/2022",
#         "expires": "05/29/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "02/08/2022",
#         "expires": "02/08/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Angela Collier",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "05/18/2022",
#         "expires": "05/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Clay Estrada",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "03/18/2022",
#         "expires": "03/18/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "06/16/2022",
#         "expires": "06/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kristina Gay",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "10/21/2022",
#         "expires": "10/21/2023",
#         "expired_status": "expires_soon"
#       },
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "08/03/2022",
#         "expires": "08/03/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Diana Munoz",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "10/03/2022",
#         "expires": "10/03/2023",
#         "expired_status": "expires_soon"
#       },
#       {
#         "name": "Medical Records",
#         "timestamp": "06/13/2022",
#         "expires": "06/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Eden Nash",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "02/03/2022",
#         "expires": "02/03/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Brennen Howell",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "12/27/2021",
#         "expires": "12/27/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mara Roy",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "12/24/2021",
#         "expires": "12/24/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Matilda Alvarado",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "05/14/2022",
#         "expires": "05/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Daphne Hinton",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "08/13/2022",
#         "expires": "08/13/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "10/02/2022",
#         "expires": "10/02/2023",
#         "expired_status": "expires_soon"
#       },
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "02/17/2022",
#         "expires": "02/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Haley Malone",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "03/08/2022",
#         "expires": "03/08/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "10/09/2022",
#         "expires": "10/09/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Geovanni Hess",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "02/25/2022",
#         "expires": "02/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Oswaldo Gould",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "05/25/2022",
#         "expires": "05/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mackenzie Parrish",
#     "completions": [
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "02/15/2022",
#         "expires": "02/15/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kingston Gay",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "06/13/2022",
#         "expires": "06/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jon Chapman",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "01/12/2022",
#         "expires": "01/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Elizabeth Esparza",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "06/17/2022",
#         "expires": "06/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Makenzie Pollard",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "05/13/2022",
#         "expires": "05/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Tristian Myers",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "04/17/2022",
#         "expires": "04/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Penelope Whitney",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "02/21/2022",
#         "expires": "02/21/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Zachery Sherman",
#     "completions": [
#       {
#         "name": "Physical Science Responsible Conduct of Research Course 1.",
#         "timestamp": "01/13/2022",
#         "expires": "01/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jazmine Haynes",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "10/22/2022",
#         "expires": "10/22/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Alina Barry",
#     "completions": [
#       {
#         "name": "Electrical Safety for Labs",
#         "timestamp": "12/28/2021",
#         "expires": "12/28/2022",
#         "expired_status": "expired"
#       },
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "08/06/2022",
#         "expires": "08/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Niko Maldonado",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "03/13/2022",
#         "expires": "03/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Frances Fields",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "07/13/2022",
#         "expires": "07/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jamiya Oconnell",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "06/23/2022",
#         "expires": "06/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lorenzo Delacruz",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "12/18/2021",
#         "expires": "12/18/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Saige Mcdonald",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "02/02/2022",
#         "expires": "02/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mina Hatfield",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "01/28/2022",
#         "expires": "01/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Giselle Oneal",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "05/09/2022",
#         "expires": "05/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lucy Duarte",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "05/24/2022",
#         "expires": "05/24/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Brogan Dorsey",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "07/25/2022",
#         "expires": "07/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Conner Warner",
#     "completions": [
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "03/11/2022",
#         "expires": "03/11/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Madeline Davila",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "12/15/2021",
#         "expires": "12/15/2022",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Occupational Exposure to Bloodborne Pathogens",
#         "timestamp": "09/02/2022",
#         "expires": "09/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mckenna Sanders",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "06/20/2022",
#         "expires": "06/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Harper Peterson",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "03/10/2022",
#         "expires": "03/10/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Sophie Rasmussen",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "01/02/2022",
#         "expires": "01/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Immanuel Combs",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "05/06/2022",
#         "expires": "05/06/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "02/19/2022",
#         "expires": "02/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Tate Morgan",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "09/11/2022",
#         "expires": "09/11/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Frida Mosley",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "07/30/2022",
#         "expires": "07/30/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jaylynn Harmon",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "04/06/2022",
#         "expires": "04/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Nyasia Wilcox",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "04/17/2022",
#         "expires": "04/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Chaya Reynolds",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "02/02/2022",
#         "expires": "02/02/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "10/04/2022",
#         "expires": "10/04/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Marie Boone",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "02/22/2022",
#         "expires": "02/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Regan Holloway",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "12/19/2021",
#         "expires": "12/19/2022",
#         "expired_status": "expired"
#       },
#       {
#         "name": "IRB Quiz",
#         "timestamp": "01/25/2022",
#         "expires": "01/25/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Angel Hill",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "07/25/2022",
#         "expires": "07/25/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "07/02/2022",
#         "expires": "07/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mohammed Michael",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "08/11/2022",
#         "expires": "08/11/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Milagros Montes",
#     "completions": [
#       {
#         "name": "IRB Quiz",
#         "timestamp": "08/21/2022",
#         "expires": "08/21/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "02/19/2022",
#         "expires": "02/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Max Andrade",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "04/19/2022",
#         "expires": "04/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jessica Mcdaniel",
#     "completions": [
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "08/03/2022",
#         "expires": "08/03/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Harmony Lester",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "01/06/2022",
#         "expires": "01/06/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "04/27/2022",
#         "expires": "04/27/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Gillian Valdez",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "10/31/2022",
#         "expires": "10/31/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Dario Browning",
#     "completions": [
#       {
#         "name": "IRB Quiz",
#         "timestamp": "02/24/2022",
#         "expires": "02/24/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Elvis Hester",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "05/14/2022",
#         "expires": "05/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Gloria Mccarty",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "10/20/2022",
#         "expires": "10/20/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Santos Haas",
#     "completions": [
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "05/28/2022",
#         "expires": "05/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Melissa Flores",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "02/21/2022",
#         "expires": "02/21/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Dahlia Werner",
#     "completions": [
#       {
#         "name": "Physical Science Responsible Conduct of Research Course 1.",
#         "timestamp": "02/03/2022",
#         "expires": "02/03/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Emmalee Collins",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "03/10/2022",
#         "expires": "03/10/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Cooper Roberson",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "02/03/2022",
#         "expires": "02/03/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Yael Strickland",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "07/04/2022",
#         "expires": "07/04/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Ann Prince",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "03/08/2022",
#         "expires": "03/08/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lucy Dunn",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "09/02/2022",
#         "expires": "09/02/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "01/23/2022",
#         "expires": "01/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jake Gillespie",
#     "completions": [
#       {
#         "name": "IRB Quiz",
#         "timestamp": "09/02/2022",
#         "expires": "09/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Nadia Ali",
#     "completions": [
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "10/08/2022",
#         "expires": "10/08/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Julissa Bradford",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "12/22/2021",
#         "expires": "12/22/2022",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "05/13/2022",
#         "expires": "05/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Roman Moyer",
#     "completions": [
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "03/30/2022",
#         "expires": "03/30/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "09/09/2022",
#         "expires": "09/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Alejandro Cantrell",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "09/14/2022",
#         "expires": "09/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Nadia Dominguez",
#     "completions": [
#       {
#         "name": "Awareness Training for the Transport of Hazardous Material",
#         "timestamp": "05/20/2022",
#         "expires": "05/20/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "07/26/2022",
#         "expires": "07/26/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Paxton Marsh",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "12/23/2021",
#         "expires": "12/23/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Adelaide Moore",
#     "completions": [
#       {
#         "name": "Medical Records",
#         "timestamp": "01/28/2022",
#         "expires": "01/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Nathanial Leonard",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "02/06/2022",
#         "expires": "02/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Yael Cummings",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "02/26/2022",
#         "expires": "02/26/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "04/17/2022",
#         "expires": "04/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Liberty Miles",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "05/27/2022",
#         "expires": "05/27/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "07/08/2022",
#         "expires": "07/08/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "04/21/2022",
#         "expires": "04/21/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Linda Romero",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "03/14/2022",
#         "expires": "03/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kiersten Leon",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "05/22/2022",
#         "expires": "05/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Adan Salazar",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "01/23/2022",
#         "expires": "01/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Sierra Watkins",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "10/03/2022",
#         "expires": "10/03/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Garrett Mcneil",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "09/10/2022",
#         "expires": "09/10/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Travis Bowers",
#     "completions": [
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "05/07/2022",
#         "expires": "05/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Cody Day",
#     "completions": [
#       {
#         "name": "Electrical Safety for Labs",
#         "timestamp": "07/16/2022",
#         "expires": "07/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kyson Orozco",
#     "completions": [
#       {
# ...
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "07/09/2022",
#         "expires": "07/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mia Pacheco",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "01/11/2022",
#         "expires": "01/11/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Charlee Acevedo",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "09/27/2022",
#         "expires": "09/27/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Albert Rogers",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "02/06/2022",
#         "expires": "02/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Reynaldo Kidd",
#     "completions": [
#       {
#         "name": "DOT Hazard Material Awareness",
#         "timestamp": "09/22/2022",
#         "expires": "09/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jean Preston",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "06/18/2022",
#         "expires": "06/18/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Samara Tran",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "06/18/2022",
#         "expires": "06/18/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "10/26/2022",
#         "expires": "10/26/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Jerimiah Guerra",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "12/15/2021",
#         "expires": "12/15/2022",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "04/12/2022",
#         "expires": "04/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Damon Jimenez",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "04/20/2022",
#         "expires": "04/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Andreas Hoover",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "12/14/2021",
#         "expires": "12/14/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Maritza Ryan",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "05/27/2022",
#         "expires": "05/27/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Zechariah Dominguez",
#     "completions": [
#       {
#         "name": "Safe Handling of Human Cell Lines/Materials in a Research Laboratory",
#         "timestamp": "08/16/2022",
#         "expires": "08/16/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Janiyah Vaughan",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "04/07/2022",
#         "expires": "04/07/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "OHS Training",
#         "timestamp": "12/22/2021",
#         "expires": "12/22/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Rene Gardner",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "06/13/2022",
#         "expires": "06/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Derek Wells",
#     "completions": [
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "06/14/2022",
#         "expires": "06/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kaitlyn Orozco",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "04/18/2022",
#         "expires": "04/18/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Radiation Safety Annual Refresher",
#         "timestamp": "01/12/2022",
#         "expires": "01/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Anastasia Mcknight",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "04/05/2022",
#         "expires": "04/05/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Erin Swanson",
#     "completions": [
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "12/08/2021",
#         "expires": "12/08/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Ezra Powers",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "10/17/2022",
#         "expires": "10/17/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Teagan Nielsen",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "08/13/2022",
#         "expires": "08/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jazmine Alvarado",
#     "completions": [
#       {
#         "name": "Electrical Safety for Labs",
#         "timestamp": "04/07/2022",
#         "expires": "04/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lance Mcfarland",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "12/30/2021",
#         "expires": "12/30/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Randall Marsh",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "09/29/2022",
#         "expires": "09/29/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jadon Villarreal",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "05/28/2022",
#         "expires": "05/28/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "08/19/2022",
#         "expires": "08/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Dennis Dunn",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "02/21/2022",
#         "expires": "02/21/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "09/07/2022",
#         "expires": "09/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Alicia Mays",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "07/25/2022",
#         "expires": "07/25/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "01/22/2022",
#         "expires": "01/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Micah Barrera",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "08/08/2022",
#         "expires": "08/08/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "07/20/2022",
#         "expires": "07/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Marisol Cooper",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "05/10/2022",
#         "expires": "05/10/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "05/23/2022",
#         "expires": "05/23/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "04/13/2022",
#         "expires": "04/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Damari Short",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "08/22/2022",
#         "expires": "08/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Crystal Middleton",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "12/17/2021",
#         "expires": "12/17/2022",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Freddy Bullock",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "09/22/2022",
#         "expires": "09/22/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Finley Thornton",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "04/12/2022",
#         "expires": "04/12/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Mark Griffith",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "05/06/2022",
#         "expires": "05/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Wendy Bradshaw",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "02/28/2022",
#         "expires": "02/28/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Eve Sullivan",
#     "completions": [
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "01/22/2022",
#         "expires": "01/22/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "02/17/2022",
#         "expires": "02/17/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jaden Wolfe",
#     "completions": [
#       {
#         "name": "Animal Care And Use Risk Assessment",
#         "timestamp": "07/25/2022",
#         "expires": "07/25/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "09/19/2022",
#         "expires": "09/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kailey Montgomery",
#     "completions": [
#       {
#         "name": "Laboratory Safety Training",
#         "timestamp": "01/02/2022",
#         "expires": "01/02/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "OHS Training",
#         "timestamp": "04/19/2022",
#         "expires": "04/19/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Misael Sawyer",
#     "completions": [
#       {
#         "name": "Health Screening Questionnaire",
#         "timestamp": "01/20/2022",
#         "expires": "01/20/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "04/20/2022",
#         "expires": "04/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jadyn Cuevas",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "07/14/2022",
#         "expires": "07/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Cailyn Morrow",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "08/20/2022",
#         "expires": "08/20/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Lia Mosley",
#     "completions": [
#       {
#         "name": "Understanding Biosafety",
#         "timestamp": "06/09/2022",
#         "expires": "06/09/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Adrienne Yates",
#     "completions": [
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "07/07/2022",
#         "expires": "07/07/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Nayeli Mcfarland",
#     "completions": [
#       {
#         "name": "Federally Required RCR Training - Must be delivered by PI (Not available online)",
#         "timestamp": "10/08/2022",
#         "expires": "10/08/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Clarence Moran",
#     "completions": [
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "01/10/2022",
#         "expires": "01/10/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Chemical Waste Requirements",
#         "timestamp": "07/13/2022",
#         "expires": "07/13/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Audrina Valencia",
#     "completions": [
#       {
#         "name": "X-Ray Safety",
#         "timestamp": "08/30/2022",
#         "expires": "08/30/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Kamron Tanner",
#     "completions": [
#       {
#         "name": "Safety Practices and Procedures to Prevent Zoonotic Diseases While Working With Cattle",
#         "timestamp": "04/18/2022",
#         "expires": "04/18/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "NIH Guidelines Overview",
#         "timestamp": "07/06/2022",
#         "expires": "07/06/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Arnav Meza",
#     "completions": [
#       {
#         "name": "Electrical Safety for Labs",
#         "timestamp": "10/03/2022",
#         "expires": "10/03/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "Anahi Golden",
#     "completions": [
#       {
#         "name": "Using Hazardous Chemicals in an Animal Care Facility",
#         "timestamp": "02/02/2022",
#         "expires": "02/02/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Julien Terrell",
#     "completions": [
#       {
#         "name": "IRB Quiz",
#         "timestamp": "03/30/2022",
#         "expires": "03/30/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Transportation of Infectious Substances, Category B",
#         "timestamp": "02/23/2022",
#         "expires": "02/23/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Ricardo Barber",
#     "completions": [
#       {
#         "name": "Retraining in working with the IACUC",
#         "timestamp": "10/12/2022",
#         "expires": "10/12/2023",
#         "expired_status": "expires_soon"
#       }
#     ]
#   },
#   {
#     "name": "John Montes",
#     "completions": [
#       {
#         "name": "Basic Training Program for Animal Users",
#         "timestamp": "09/04/2022",
#         "expires": "09/04/2023",
#         "expired_status": "expired"
#       },
#       {
#         "name": "Radioactive Materials Safety Training",
#         "timestamp": "03/15/2022",
#         "expires": "03/15/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Camden Ho",
#     "completions": [
#       {
#         "name": "Working in Cold Temperatures",
#         "timestamp": "08/27/2022",
#         "expires": "08/27/2023",
#         "expired_status": "expired"
#       }
#     ]
#   },
#   {
#     "name": "Jadon Harrell",
#     "completions": [
#       {
#         "name": "OHS Training",
#         "timestamp": "03/14/2022",
#         "expires": "03/14/2023",
#         "expired_status": "expired"
#       }
#     ]
#   }
# ]
